# %%
import pandas as pd
import numpy as np

# %%
cluster_base = pd.read_csv('data/datasets/cluster_split_base_set.csv')
random_base = pd.read_csv('data/datasets/random_split_base_set.csv')
pct_inh_saifudeen_data = pd.read_csv('data/saifudeen_2026_raw/raw_percent_inhibition_full_set.csv')

# %%
print(cluster_base)
# Out:
#          index                  Activity_ID Quality  \
# 0            0  AAAAKTROWFNLEP_on_P49137_WT     Low
# 1            1  AAAAZQPHATYWOK_on_P00533_WT    High
# 2            2  AAAAZQPHATYWOK_on_P04626_WT    High
# 3            3  AAABTPAECTZDET_on_P06239_WT    High
# 4            4  AAACBXVBBDAYRQ_on_Q5S007_WT    High
# ...        ...                          ...     ...
# 340484  438888  ZZZRHFQPNAABMT_on_P49336_WT    High
# 340485  438889  ZZZWPOWGYZGAQZ_on_P07333_WT    High
# 340486  438890  ZZZWPOWGYZGAQZ_on_P35968_WT     Low
# 340487  438891  ZZZXGPGVDJDFCJ_on_O00311_WT     Low
# 340488  438892  ZZZZEECYUGCIIB_on_Q16539_WT    High
#
#                                 source  \
# 0                             ChEMBL34
# 1       ChEMBL34;Sharma2016;Sharma2016
# 2                   ExCAPE-DB;ChEMBL34
# 3                   ChEMBL34;ExCAPE-DB
# 4                             ChEMBL34
# ...                                ...
# 340484                        ChEMBL34
# ...
